# %% [markdown]
# # How Jupyter Notebooks Work
#
# A [Jupyter Notebook](https://jupyter.org/) is a document that combines code (Python) with formatted text (in the form of [Markdown](https://en.wikipedia.org/wiki/Markdown)). It can be used for group teaching or independent learning.

# %% [markdown]
# ## Text Blocks
#
# This is a text block! Try clicking on it to see the content. Click the checkmark button at top right to turn it into the visual form again.

# %% [markdown]
# Text is not very exciting, but some cool things Markdown can do...
#
# * Bullet points, like this.
#
# [Links](https://www.youtube.com/watch?v=dQw4w9WgXcQ).
#
# <br>
# <details><summary>Click to see</summary>
#
# > Hidden text
# </details>

# %% [markdown]
# ## Code Blocks
#
# Code blocks can be run within the notebook! They usually have some kind of output. Try running this next one.
#
# ... The very first time you run it, you'll probably be asked to install `ipykernel`. To do that,
#
# 1. Click `Terminal` at the top of this window
# 2. Enter this line:<br>
# `pip install -U ipykernel`
# 3. Wait
#
# Now try running the below. You may have some more prompts to go through... Click `Yes` or `Install` on each one.

# %%
# Your first block of code in a notebook
print("Hi there! You ran me!")

# %% [markdown]
# See how that text appeared under the cell? That's the evidence that you ran it. You can also clear it and run it again using the `...` at the left of the cell.
#
# ### Input
#
# Some cells have input. In VSCode, this will cause a prompt to appear at the TOP of the screen for you type something and hit `Enter`. What you type is then sent to the cell. Try this one.

# %%
# A block of code with input
name = input("Enter your name: ")
print(f"Hi, {name}!")

# %% [markdown]
# If you run it again and enter something different, the output will change. Try it!
#
# ### Memory
#
# Each of the cells in a notebook shares memory with the others once it's been run. Consider what happens if you run this one.

# %%
# Shared memory
print(f"Your name last time was {name}")

# %% [markdown]
# Hmm. **If** you ran the previous cell, your name has been stored, and you didn't need to enter it again.

# %% [markdown]
# ## Off you go
#
# OK, that's all for now. Proceed to the next notebook — your first one learning some Python!
